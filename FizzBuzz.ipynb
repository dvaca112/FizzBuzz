# %% [markdown]
# <a href="https://colab.research.google.com/github/DillyWilly112/FizzBuzz/blob/main/FizzBuzz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fizzBuzz = [1, 2, 'Fizz', 4, 'Buzz', 'Fizz', 7, 8, 'Fizz', 'Buzz', 11, 'Fizz', 13, 14,  'FizzBuzz', 16, 17, 'Fizz', 19, 'Buzz']
for x in fizzBuzz:
  print(x)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
